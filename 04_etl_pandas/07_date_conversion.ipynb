# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\engenharia de dados\curso udemy\Arquivos\04.+ETL+Pandas\04. ETL Pandas\arquivos_csv\Clientes.csv", delimiter=',')
df.head()
# Out:
#    id           created_at first_name last_name                email  \
# 0   0  2017-11-01 14:45:41      Marta     Jesus                  NaN
# 1   1  2017-10-16 00:50:39      Luana   Almeida                  NaN
# 2   2  2018-06-16 17:51:29      Frida    Mendes  frida@meu_email.com
# 3   3  2018-01-17 03:02:58    Daniela   Avelino  daniela@exemplo.com
# 4   4  2018-08-06 07:24:16    Romário  Teixeira                  NaN
#
#     cell_phone country              state  \
# 0  9 9102-7834  Brasil               Acre
# 1  9 7328-8718  Brasil  Rio Grande do Sul
# 2  9 5906-7552  Brasil          São Paulo
# 3  9 4642-9486  Brasil        Mato Grosso
# 4  9 3093-6522  Brasil              Bahia
#
#                                    street  number  additionals
# 0                                     NaN     NaN  Conjunto 16
# 1  Avenida 56 do Estado Rio Grande do Sul   989.0  Conjunto 17
# 2          Avenida 59 do Estado São Paulo   534.0          NaN
# ...

# %%
print(df['created_at'].dtypes)
# Out:
# object

# %%
df['created_at'] = pd.to_datetime(df['created_at'])

# %%
print(df['created_at'].dtypes)
# Out:
# datetime64[ns]

# %% [markdown]
# Filter Date

# %%
df_filtrado = df[(df['created_at'].dt.year >= 2018) & (df['created_at'].dt.year <= 2020)]
df_filtrado.head()
# Out:
#    id          created_at first_name last_name                  email  \
# 2   2 2018-06-16 17:51:29      Frida    Mendes    frida@meu_email.com
# 3   3 2018-01-17 03:02:58    Daniela   Avelino    daniela@exemplo.com
# 4   4 2018-08-06 07:24:16    Romário  Teixeira                    NaN
# 5   5 2018-01-05 17:20:49    Marcelo   Barroso                    NaN
# 6   6 2018-06-18 11:17:42  Cristiano    Elísio  cristiano@exemplo.com
#
#     cell_phone country              state                              street  \
# 2  9 5906-7552  Brasil          São Paulo      Avenida 59 do Estado São Paulo
# 3  9 4642-9486  Brasil        Mato Grosso                                 NaN
# 4  9 3093-6522  Brasil              Bahia            Praça 56 do Estado Bahia
# 5  9 2830-2088  Brasil  Rio Grande do Sul  Rua 28 do Estado Rio Grande do Sul
# 6  9 3532-8404  Brasil              Goiás              Rua 78 do Estado Goiás
#
#    number  additionals
# 2   534.0          NaN
# 3     NaN          NaN
# ...

# %%
df_dt2 = df[(df['created_at'].dt.year == 2018) & (df['created_at'].dt.month == 1)]
df_dt2.head()
# Out:
#     id          created_at first_name last_name                  email  \
# 3    3 2018-01-17 03:02:58    Daniela   Avelino    daniela@exemplo.com
# 5    5 2018-01-05 17:20:49    Marcelo   Barroso                    NaN
# 36  36 2018-01-26 03:29:13    Mariana      Góes  mariana@meu_email.com
# 43  43 2018-01-07 07:54:22    Daniela      Lima                    NaN
# 54  54 2018-01-25 02:11:25      Diego  Teixeira      diego@exemplo.com
#
#      cell_phone country              state  \
# 3   9 4642-9486  Brasil        Mato Grosso
# 5   9 2830-2088  Brasil  Rio Grande do Sul
# 36  9 7324-4293  Brasil                NaN
# 43  9 1763-2584  Brasil     Rio de Janeiro
# 54  9 5247-1737  Brasil               Pará
#
#                                 street  number  additionals
# 3                                  NaN     NaN          NaN
# 5   Rua 28 do Estado Rio Grande do Sul   805.0  Conjunto 13
# 36                                 NaN     NaN      Apto 25
# ...

# %% [markdown]
# Converting to Brazilian format

# %%
print(df['created_at'].dtypes)
# Out:
# datetime64[ns]

# %%
df['created_at'] = df['created_at'].dt.strftime('%d/%m/%Y')
df.head()
# Out:
#    id  created_at first_name last_name                email   cell_phone  \
# 0   0  01/11/2017      Marta     Jesus                  NaN  9 9102-7834
# 1   1  16/10/2017      Luana   Almeida                  NaN  9 7328-8718
# 2   2  16/06/2018      Frida    Mendes  frida@meu_email.com  9 5906-7552
# 3   3  17/01/2018    Daniela   Avelino  daniela@exemplo.com  9 4642-9486
# 4   4  06/08/2018    Romário  Teixeira                  NaN  9 3093-6522
#
#   country              state                                  street  number  \
# 0  Brasil               Acre                                     NaN     NaN
# 1  Brasil  Rio Grande do Sul  Avenida 56 do Estado Rio Grande do Sul   989.0
# 2  Brasil          São Paulo          Avenida 59 do Estado São Paulo   534.0
# 3  Brasil        Mato Grosso                                     NaN     NaN
# 4  Brasil              Bahia                Praça 56 do Estado Bahia   191.0
#
#    additionals
# 0  Conjunto 16
# 1  Conjunto 17
# ...

# %% [markdown]
# Converting to Brazilian format in a single script

# %%
import pandas as pd
df_single = pd.read_csv(r"D:\engenharia de dados\curso udemy\Arquivos\04.+ETL+Pandas\04. ETL Pandas\arquivos_csv\Clientes.csv", delimiter=',')
df_single['created_at'] = pd.to_datetime(df_single['created_at'])
df_single['created_at'] = df_single['created_at'].dt.strftime('%d/%m/Y %H:%M:%S')
df_single.head()
# Out:
#    id        created_at first_name last_name                email  \
# 0   0  01/11/Y 14:45:41      Marta     Jesus                  NaN
# 1   1  16/10/Y 00:50:39      Luana   Almeida                  NaN
# 2   2  16/06/Y 17:51:29      Frida    Mendes  frida@meu_email.com
# 3   3  17/01/Y 03:02:58    Daniela   Avelino  daniela@exemplo.com
# 4   4  06/08/Y 07:24:16    Romário  Teixeira                  NaN
#
#     cell_phone country              state  \
# 0  9 9102-7834  Brasil               Acre
# 1  9 7328-8718  Brasil  Rio Grande do Sul
# 2  9 5906-7552  Brasil          São Paulo
# 3  9 4642-9486  Brasil        Mato Grosso
# 4  9 3093-6522  Brasil              Bahia
#
#                                    street  number  additionals
# 0                                     NaN     NaN  Conjunto 16
# 1  Avenida 56 do Estado Rio Grande do Sul   989.0  Conjunto 17
# 2          Avenida 59 do Estado São Paulo   534.0          NaN
# ...
