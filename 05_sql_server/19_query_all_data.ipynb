# %%
import pandas as pd
import pyodbc 

server = 'DESKTOP-505F0PE' # Substitua pelo nome do servidor SQL Server
database = 'Python'  # Substitua pelo nome do banco de dados
conexaoDB = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};'
                      f'SERVER={server};'
                      f'DATABASE={database};'
                      'Trusted_Connection=yes;')

cursor = conexaoDB.cursor()   # criando cursor de comando '

# %%
Query = """

select
T1.id,
T1.total_price,
T2.created_at,
T2.status,
T4.Categoria,
T3.Nome as Produto,
T5.first_name as NomeCliente,
T5.email,
T5.cell_phone as Telefone,
T5.state as Estado
from Items as T1
Left Join Ordens as T2 on T1.order_id = T2.id
Left Join Produtos as T3 on T1.product_id = T3.ID
Left Join Categoria as T4 on T3.Id_Category = T4.ID
Left Join Clientes as T5 on T2.customer_id = T5.id


"""

# %%
Join = pd.read_sql(Query,conexaoDB)
Join.head(10)
# Out:
# C:\Users\nicon\AppData\Local\Temp\ipykernel_18452\2881997810.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   Join = pd.read_sql(Query,conexaoDB)
#       id  total_price          created_at    status                Categoria  \
# 0  10682        377.0 2019-08-28 03:36:31  entregue              Eletrônicos
# 1  15650         10.0 2019-08-28 03:36:31  entregue  Cosméticos e Perfumaria
# 2  19082         20.0 2019-08-28 03:36:31  entregue                   Livros
# 3  26312         92.0 2019-08-28 03:36:31  entregue                   Livros
# 4  26347       2304.0 2019-08-28 03:36:31  entregue                Celulares
# 5  43593       4119.0 2019-08-28 03:36:31  entregue         Eletrodomésticos
# 6  13271         45.0 2019-08-16 20:21:30  entregue                   Livros
# ...
